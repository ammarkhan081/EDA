# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Load the dataset

# %%
file_path = "C:/Users/FCT/Downloads/salary_02.csv"
salary_data = pd.read_csv(file_path)
salary_data
# Out:
#      year experience employment_type                  job_title  salary  remote_ratio
# 0    2021         EN              FT               Data Analyst    6072           0.0
# 1    2021         SE              FT              Data Engineer   33511           0.0
# 2   2022e         SE              FT     Principal Data Analyst  170000         100.0
# 3   2022e         SE              FT              Data Engineer   96833          50.0
# 4   2022e         MI              FT              Data Engineer   13105           0.0
# ..    ...        ...             ...                        ...     ...           ...
# 62   2021         MI              FT      Business Data Analyst  135000         100.0
# 63  2022e         EN              FT  Machine Learning Engineer   21844          50.0
# 64   2021         SE              FT         Lead Data Engineer  125000           NaN
# 65   2021         EN              FT             Data Scientist   51321           0.0
# ...

# %% [markdown]
# # Checking null values

# %%
salary_data.isnull().sum()
# Out:
# year               0
# experience         0
# employment_type    0
# job_title          0
# salary             0
# remote_ratio       3
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
salary_data['remote_ratio'].fillna(value=salary_data['remote_ratio'].median(), inplace=True)
# Out:
# C:\Users\FCT\AppData\Local\Temp\ipykernel_16836\158334192.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   salary_data['remote_ratio'].fillna(value=salary_data['remote_ratio'].median(), inplace=True)

# %%
salary_data.isnull().sum()
# Out:
# year               0
# experience         0
# employment_type    0
# job_title          0
# salary             0
# remote_ratio       0
# dtype: int64

# %% [markdown]
# # Descriptive Statistics

# %%
salary_data['salary'].describe()
# Out:
# count        67.000000
# mean      95803.611940
# std       62975.263124
# min        6072.000000
# 25%       52779.500000
# 50%       85000.000000
# 75%      130000.000000
# max      270000.000000
# Name: salary, dtype: float64

# %% [markdown]
# # Histogram

# %%
plt.figure(figsize=(15, 5))
sns.histplot(salary_data['salary'], bins=15, kde=False, color='red')
plt.title("Histogram of Salaries")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Box Plot

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(y=salary_data['salary'])
plt.title("Box Plot of Salaries")
plt.xlabel("Salary")
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
plt.figure(figsize=(8, 4))
sns.scatterplot(x=salary_data['experience'], y=salary_data['salary'], color='black')
plt.title("Scatter Plot: Experience vs Salary")
plt.show()

# %% [markdown]
# # PDF using KDE

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(salary_data['salary'], fill=True, color='blue', alpha=0.6)
plt.title("Probability Density Function (PDF) of Salaries")
plt.show()

# %% [markdown]
# ### Conclusion:
# 1. The salary data is concentrated within a specific range, as shown by both the histogram and PDF.
# 2. The PDF highlights that the highest density of salaries lies within a particular range (e.g., 50k-75k).
# 3. The box plot reveals potential outliers, indicating some employees earn significantly more or less than the majority.
# 4. The scatter plot suggests a positive relationship between experience and salary, although further analysis may be needed to confirm this trend.
